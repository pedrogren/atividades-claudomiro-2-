# %% [markdown]
# ## Questões Memória RAM
# **Docente**: Claudomiro de Souza Sales Junior\
# **Discente**: luiz Pedro de Araújo Amorim

# %% [markdown]
# # **Questão 4.1**

# %% [markdown]
# Para uma memória com **2K células** e **16 bits por célula**:\n
# *   **A. Tamanho de cada endereço:** Precisamos de **11 bits** para endereçar 2K células, pois $2K = 2 \times 1024 = 2^{11}$.\n
# *   **B. Valor total de bits (T):** O total é de **32K bits**. Isso porque $2^{11} \text{ células} \times 16 \text{ bits/célula} = 2^{11} \times 2^4 = 2^{15} \text{ bits}$. Como $2^{10} = 1K$, então $2^{15} = 2^5 \times 2^{10} = 32K \text{ bits}$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Passo a passo do Exemplo 4.2
#
# Para resolver esse problema, primeiro precisamos descobrir o **total de células** que essa memória consegue utilizar. O enunciado informa que a capacidade máxima de armazenamento é de **256K bits** e que cada célula individual guarda **8 bits**. Fazendo uma conta simples de divisão, pegamos os **256K** e dividimos pelo tamanho da célula, o que resulta em **32K células** no total.
#
# ## Como achar o tamanho do endereço
#
# Depois de encontrar a quantidade de células, precisamos descobrir quantos bits são necessários para formar os **endereços** dessa memória. A regra fundamental é que o número total de células é igual a **2 elevado à quantidade de bits do endereço**. Como já vimos que a memória tem **32K células**, e sabemos que **32** é o mesmo que **2 elevado a 5** e o **K** (quilo) representa **2 elevado a 10**, somamos as potências e descobrimos que **32K** é igual a **2 elevado a 15**. Portanto, o **tamanho de cada endereço** é de **15 bits**.

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png]())![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Resolução do Exemplo 4.3
#
# Para resolver o **Exemplo 4.3**, precisamos analisar as características da Memória Principal (MP) fornecidas: uma capacidade de **2K palavras**, sendo que cada palavra possui **16 bits**. O problema pede o tamanho dos registradores **REM** e **RDM**, o valor do **maior endereço** e a **capacidade total** em bits.
#
# ## Tamanho dos Registradores REM e RDM
#
# O **RDM (Registrador de Dados da Memória)** tem a função de armazenar temporariamente a informação que está sendo transferida entre o processador e a memória. O tamanho deste registrador deve ser igual ao tamanho da unidade de transferência da memória, que neste exemplo é a palavra de **16 bits**. Portanto, o **RDM possui 16 bits**.
#
# Já o **REM (Registrador de Endereços da Memória)** é responsável por guardar o endereço da célula que será acessada para uma leitura ou escrita. O seu tamanho em bits depende da quantidade total de endereços disponíveis na memória. Como a memória tem **2K endereços** e sabemos que **1K** equivale a **1024** ($2^{10}$), o total de endereços é **2048** ($2^{11}$). Seguindo a regra de que o número de endereços $N = 2^E$ (onde $E$ é o número de bits), descobrimos que o **REM possui 11 bits**.
#
# ## Valor do Maior Endereço da MP
#
# Em qualquer memória organizada sequencialmente, os endereços começam no número **0** e vão até o total de células menos um, ou seja, **N - 1**.
#
# Como calculamos que esta memória possui um total de **2048 posições** de armazenamento (2K), basta subtrair um para encontrar o último endereço:
# *   **2048 - 1 = 2047**.
#
# Portanto, o **valor do maior endereço** dessa memória é **2047** em decimal. Se representarmos esse valor em binário, ele será formado por uma sequência de **11 bits** (todos com valor 1), que é exatamente a capacidade total do registrador **REM**.
#
# ## Quantidade Total de Bits Armazenados
#
# A quantidade total de bits (**T**) que uma memória pode guardar é o resultado da multiplicação do número de células (**N**) pelo tamanho de cada célula (**M**).
#
# Fazendo a conta para este exemplo:
# *   **N** (total de células) = **2048** (ou 2K).
# *   **M** (tamanho da célula) = **16 bits**.
# *   **T = 2048 x 16 = 32.768 bits**.
#
# Para facilitar a leitura, podemos expressar esse valor na unidade **K** (quilo). Como **1K** bits são **1024** bits, dividimos o total por 1024:
# *   **32.768 / 1024 = 32**.
#
# A **quantidade total de bits** que podem ser armazenados nesta memória é de **32K bits**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Resolução do Exemplo 4.4
#
# Para resolver este problema, precisamos analisar as capacidades dos registradores e a forma como o processador conversa com a memória. Temos um **RDM de 32 bits** e um **REM de 24 bits**, além da informação de que **duas células** são lidas por vez.
#
# ## Capacidade máxima de endereçamento
#
# A capacidade de endereçamento é definida pelo tamanho do **REM** (Registrador de Endereços da Memória). Como o REM possui **24 bits**, o número total de endereços diferentes que o processador consegue indicar é calculado fazendo **2 elevado a 24**.
#
# Sabemos que **2 elevado a 4** é 16 e **2 elevado a 20** representa o prefixo Mega (M). Portanto, a capacidade máxima de endereçamento desse microcomputador é de **16M células** (ou 16.777.216 posições de memória).
#
# ## Tamanho da palavra e de cada célula
#
# O enunciado diz que o **RDM** tem capacidade para **32 bits** e que o barramento de dados tem o mesmo tamanho da palavra. Isso significa que a **palavra da máquina possui 32 bits**.
#
# Também foi dito que, em cada acesso à memória, são lidas **duas células** de uma vez para preencher essa palavra. Se 32 bits correspondem a duas células, basta dividir esse valor por dois para descobrir que **cada célula possui 16 bits**.
#
# ## Total máximo de bits na memória RAM
#
# Para achar o total de bits que a memória pode guardar, multiplicamos a quantidade de endereços (células) pelo tamanho de bits de cada célula.
#
# Já calculamos que a memória tem **16M células** e que cada uma guarda **16 bits**. Fazendo a conta: **16M x 16 = 256M bits**. Se quisermos transformar isso em bits usando potências, temos **2 elevado a 24** (células) vezes **2 elevado a 4** (tamanho da célula), o que resulta em **2 elevado a 28 bits**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Resolução do Exemplo 4.5
#
# Para resolver este exercício, precisamos usar as informações do processador e da capacidade da memória para encontrar as medidas de cada componente.
#
# **A) Quantidade máxima de células**
# O número total de células que podem existir é determinado pelo tamanho do **barramento de endereços (BE)**, que é o caminho que o processador usa para indicar onde a informação está. Como o BE tem **33 bits**, a conta é **2 elevado a 33**. Consultando as tabelas de prefixos, sabemos que 2 elevado a 30 é o Giga e 2 elevado a 3 é 8, portanto o sistema suporta até **8G células**.
#
# **C) Tamanho de cada célula e da palavra**
# Para descobrir o tamanho de cada célula, dividimos a capacidade total da memória pelo número de células que calculamos. O enunciado diz que a memória guarda no máximo **64G bits**. Fazendo a divisão de 64G bits por 8G células, descobrimos que **cada célula tem 8 bits**. O problema também afirma que cada célula armazena **um oitavo (1/8) de uma palavra**, então multiplicamos 8 bits por 8 e achamos que a **palavra desta máquina tem 64 bits**.
#
# **B) Tamanho do REM e do BD**
# O **REM (Registrador de Endereços da Memória)** tem a função de guardar o endereço que será acessado, por isso ele precisa ter o mesmo tamanho do barramento de endereços, resultando em **33 bits**. Já o **BD (Barramento de Dados)** é o caminho por onde a informação viaja e o enunciado diz que ele transfere **quatro palavras** por vez. Como descobrimos que cada palavra tem 64 bits, fazemos a conta de 4 vezes 64 e concluímos que o **BD possui 256 bits**.

# %% [markdown]
# ![image.png](attachment:88f5d377-a72b-474e-9876-bf9b8d8bf245.png)

# %% [markdown]
# ## Passo a passo da Questão 1
#
# O primeiro ponto é descobrir quantas **células (N)** essa memória tem. Como o **barramento de endereços** tem **12 bits**, a quantidade de posições diferentes que o processador consegue indicar é de **2 elevado a 12**.
# Fazendo a conta:
# * $2^{12} = 2^2 \times 2^{10} = 4 \times 1024 = \mathbf{4.096 \text{ células}}$.
#
# O segundo ponto é saber quanto cabe em cada célula. O enunciado diz que cada uma guarda exatamente uma **palavra de 16 bits**.
# Como o problema pede o resultado final em **bytes**, precisamos converter esse valor:
# * $16 \text{ bits} / 8 = \mathbf{2 \text{ bytes por célula}}$.
#
# ## Cálculo final da capacidade
#
# Agora que sabemos o número de células e o tamanho de cada uma, basta multiplicar os valores:
# * **Total de bytes** = $4.096 \text{ células} \times 2 \text{ bytes} = \mathbf{8.192 \text{ bytes}}$.
#
# Para simplificar o resultado usando o prefixo **K** (quilo), dividimos o total por 1024:
# * $8.192 / 1024 = \mathbf{8 \text{ KB}}$.
#
# Portanto, essa memória consegue armazenar um total de **8 KB**.

# %% [markdown]
# ![image.png](attachment:64bd10c1-0f53-4549-8d5b-7e907ed8439e.png)

# %% [markdown]
# ## Diferenças entre as Memórias A, B e C
#
# Para entender a diferença entre essas três organizações de memória, precisamos olhar para três coisas: o tamanho do **endereço** (quantos bits o processador usa para achar a célula), o **conteúdo** (quantos bits cabem em cada "caixinha") e o **total de bits** (a capacidade total de armazenamento).
#
# ## Memória A: 32K células de 8 bits
#
# Nessa organização, temos **32.768 células** (32 x 1024). Como 32K é o mesmo que **2 elevado a 15**, o tamanho do **endereço** é de **15 bits**. O **conteúdo** de cada célula é de **8 bits** (ou 1 byte). Multiplicando as células pelo tamanho de cada uma, o **total de bits** é de **256K bits** (32 x 8).
#
# ## Memória B: 16K células de 16 bits
#
# Aqui temos metade das células da Memória A, ou seja, **16.384 células** (16 x 1024). Como 16K é **2 elevado a 14**, o **endereço** é menor, com **14 bits**. Por outro lado, o **conteúdo** de cada célula é o dobro, com **16 bits**. No fim das contas, o **total de bits** é o mesmo da Memória A: **256K bits** (16 x 16), pois o que ela perdeu em número de endereços, ganhou no tamanho da célula.
#
# ## Memória C: 16K células de 8 bits
#
# Esta é a menor das três. Ela tem as mesmas **16.384 células** da Memória B, o que significa que o seu **endereço** também tem **14 bits**. No entanto, o **conteúdo** de cada célula é de apenas **8 bits**. Por isso, o seu **total de bits** é de apenas **128K bits** (16 x 8), que é a metade da capacidade das memórias A e B.
#
# ## Resumo das diferenças
#
# Comparando as três, a **Memória A** é a que precisa de mais bits para o **endereço** (15 bits). A **Memória B** é a que tem mais **conteúdo** por célula (16 bits). Já o **total de bits** mostra que as memórias **A e B** empatam na capacidade total, enquanto a **Memória C** é a mais limitada.

# %% [markdown]
# ![image.png](attachment:1f40f61d-368b-4204-aac0-1c35ba747b70.png)

# %% [markdown]
# ## Função do Registrador de Endereços de Memória (REM)
#
# O **REM** tem a função de guardar temporariamente o **endereço** da célula de memória que o processador deseja acessar. Quando o computador vai iniciar uma operação de leitura ou de escrita, ele coloca nesse registrador o número da "casa" (posição) onde a informação está ou onde ela deve ser guardada. Ele serve como uma ponte que indica para a memória qual é o local exato da operação.
#
# ## Função do Registrador de Dados da Memória (RDM)
#
# O **RDM** serve para armazenar temporariamente a **informação** propriamente dita que está viajando entre a memória principal e o processador. Se o processador está lendo algo da memória, o dado sai da célula e fica no RDM até o processador pegá-lo. Se o processador está gravando algo, ele coloca o dado no RDM primeiro para depois enviá-lo para a memória. Por isso, ele é chamado de **bidirecional**, já que os dados podem passar por ele tanto para entrar quanto para sair da memória.

# %% [markdown]
# ![image.png](attachment:d13401bb-03c2-443b-a46f-7dd5f8aad00d.png)

# %% [markdown]
# ## Barramentos que ligam o processador e a memória
#
# A comunicação entre o processador e a memória principal acontece através de três conjuntos de fios condutores, chamados de barramentos. Cada um tem uma função diferente e uma direção específica para o fluxo de sinais:
#
# **Barramento de Dados:** Esse é o caminho usado para a transferência real das informações entre o processador e a memória. Ele interliga o Registrador de Dados da Memória (RDM) à Memória Principal. Como ele serve tanto para buscar um dado (leitura) quanto para guardar um novo (escrita), o seu fluxo de sinais é **bidirecional**, ou seja, os dados podem viajar nos dois sentidos.
#
# **Barramento de Endereços:** Esse barramento serve para o processador indicar para a memória qual é o endereço exato da célula que ele deseja acessar. Ele interliga o Registrador de Endereços da Memória (REM) à Memória Principal para levar os bits que representam esse endereço. O fluxo aqui é **unidirecional**, o que significa que a informação só viaja em um sentido: do processador para a memória.
#
# **Barramento de Controle:** Por esses fios passam os sinais que comandam o que deve ser feito no sistema, como as ordens de escrita (WRITE), leitura (READ). Ele serve para coordenar as operações entre o processador e a memória principal. O fluxo desse barramento é **bidirecional**, permitindo a passagem de sinais de controle entre os componentes.\
# ![image.png](attachment:cde79d61-bb2a-49ce-80c1-94b3285b56ef.png)

# %% [markdown]
# ![image.png](attachment:ced5f9f6-c85b-42f3-a766-31fa9bc07e03.png)

# %% [markdown]
# ## Letra A - Tamanho do barramento de endereços
#
# O **REM** (Registrador de Endereços de Memória) é quem guarda o número da célula que o processador quer acessar. Como o enunciado diz que o REM desse computador consegue guardar números de **20 bits**, o **barramento de endereços** precisa ter exatamente esse mesmo tamanho para conseguir levar essa informação até a memória. Então, a resposta é **20 bits**.
#
# ## Letra B - Células lidas por vez
#
# O **RDM** (Registrador de Dados da Memória) é o lugar onde a informação fica guardada durante a viagem entre a memória e o processador. O problema diz que o RDM tem **16 bits** de espaço. Como cada célula da memória desse computador guarda apenas **8 bits**, o sistema precisa ler **2 células** ao mesmo tempo para conseguir preencher os 16 bits do RDM em uma única operação.
#
# ## Letra C - Quantidade total de bits
#
# Para saber o total de bits, primeiro precisamos descobrir quantas células existem no total. Como o endereço tem **20 bits**, a memória pode ter até **2 elevado a 20** células, o que equivale a **1 Mega (1M)** ou 1.048.576 posições.
#
# Sabendo que a memória tem **1M de células** e que cada célula guarda **8 bits**, fazemos a conta de multiplicar:
# * 1.048.576 x 8 = **8.388.608 bits**.
#
# Se quiser simplificar o nome, você pode dizer que a memória tem **8M bits**.

# %% [markdown]
# ![image.png](attachment:1e39adcf-74c9-4a2e-8793-86e4ed7a8f21.png)

# %% [markdown]
# ## Resolução da Questão 11
#
# Para resolver esse problema, vamos usar os dados de uma memória com **32K células** onde cada uma guarda **8 bits**.
#
# ## Maior endereço em decimal
# O primeiro passo é transformar o valor de **32K** em um número comum. Como cada **K** na informática vale **1024**, fazemos 32 vezes 1024 e descobrimos que a memória tem **32.768 células** no total. Como os endereços começam sempre a partir do número **0**, o maior endereço disponível será o total de células menos um, ou seja, **32.767**.
#
# ## Tamanho do barramento de endereços
# Para saber quantos bits o barramento precisa ter, usamos a regra de **2 elevado a uma potência**. Sabemos que **32** é o mesmo que **2 elevado a 5** e que **K** é **2 elevado a 10**, então somando os dois temos **2 elevado a 15**. Isso significa que o barramento de endereços desse sistema precisa ter **15 bits** para conseguir acessar todas as células.
#
# ## Bits no RDM e no REM
# O tamanho desses dois componentes depende do que eles carregam. O **REM (Registrador de Endereços)** guarda o endereço da célula, então ele terá o mesmo tamanho do barramento, que é **15 bits**. O **RDM (Registrador de Dados)** guarda a informação que está sendo lida ou gravada; como o enunciado diz que cada célula guarda **8 bits**, o RDM terá exatamente **8 bits**.
#
# ## Total máximo de bits da memória
# Para achar o total de bits que a memória suporta, multiplicamos o número de células pelo tamanho de cada uma. Fazendo a conta de **32.768 células** vezes **8 bits**, o resultado é de **262.144 bits**. Se a gente quiser simplificar esse número usando o prefixo **K**, o total é de **256K bits**.

# %% [markdown]
# ![image.png](attachment:ff13139a-96df-4b42-967f-87952f70439a.png)

# %% [markdown]
# ## Resolução da Questão 12
#
# Para resolver esse problema, vamos analisar as informações dadas: o endereço da célula é **2C81** em hexadecimal e o que está guardado dentro dela é o valor **F5A**, também em hexadecimal. O sistema lê uma célula por vez e o tamanho da célula é o mesmo tamanho da palavra.
#
# ## Tamanho do REM e do RDM
#
# O **REM** (Registrador de Endereços da Memória) precisa ter bits suficientes para guardar o número do endereço. Como o endereço **2C81** tem 4 dígitos em hexadecimal e cada dígito vale 4 bits, fazemos 4 vezes 4 e descobrimos que o **REM tem 16 bits**.
#
# O **RDM** (Registrador de Dados da Memória) guarda a informação que sai da célula. O valor **F5A** tem 3 dígitos hexadecimais, o que dá um total de **12 bits** (3 vezes 4). Como o sistema lê uma célula por vez e ela tem o tamanho da palavra, o **RDM tem 12 bits**.
#
# ## Máxima quantidade de bits da memória
#
# Para achar o total de bits, primeiro calculamos quantas células o processador consegue alcançar com o endereço que descobrimos. Como o endereço tem **16 bits**, a conta é **2 elevado a 16**, o que resulta em **64K células** (ou 65.536 posições).
#
# Agora, multiplicamos esse número total de células pelo tamanho de bits de cada uma (que é o tamanho do dado no RDM). Fazendo a conta de **65.536 células** vezes **12 bits**, chegamos ao resultado de **786.432 bits**. Se dividirmos esse valor por 1024 para simplificar, a memória pode ter no máximo **768K bits**.

# %% [markdown]
# ![image.png](attachment:82e1abae-2671-496f-88b2-d0bc46039fe9.png)

# %% [markdown]
# ## Dados fornecidos pelo exercício
# Para resolver essa questão, primeiro anotamos os valores que o enunciado nos passou:
# * **Tempo de acesso à Cache ($T_{cache}$):** 8 ns.
# * **Tempo de acesso à Memória Principal ($T_{main}$):** 70 ns.
# * **Eficiência da Cache (Taxa de Acerto):** 96% (ou 0,96).
# * **Número de acessos analisados:** 100.
#
# ## Entendendo a lógica do acesso
# O processador sempre tenta buscar a informação primeiro na **memória cache**, que é o nível mais rápido e caro da hierarquia. Se o dado estiver lá (acerto ou *hit*), o acesso é instantâneo. Se não estiver (falta ou *miss*), o sistema perde o tempo da busca na cache e ainda precisa gastar o tempo de busca na **memória principal**.
#
# Nesse sistema específico, temos dois caminhos possíveis:
# 1. **Cenário de Acerto (Hit):** Acontece em 96 dos 100 acessos. O tempo gasto é apenas de **8 ns**.
# 2. **Cenário de Falta (Miss):** Acontece nos outros 4 acessos (100 - 96). O tempo gasto é o tempo de olhar a cache (**8 ns**) mais o tempo de buscar na memória principal (**70 ns**), totalizando **78 ns**.
#
# ## Cálculo passo a passo do tempo médio
# Vamos calcular o tempo total que o processador gastou para realizar todos os 100 acessos e depois tirar a média simples:
#
# **1. Cálculo do tempo total dos acertos:**
# * 96 acessos $\times$ 8 ns = **768 ns**.
#
# **2. Cálculo do tempo total das faltas:**
# * 4 acessos $\times$ 78 ns = **312 ns**.
#
# **3. Soma do tempo total acumulado:**
# * 768 ns (acertos) + 312 ns (faltas) = **1080 ns**.
#
# **4. Divisão pelo número de acessos para achar a média:**
# * $1080 \text{ ns} / 100 \text{ acessos} = \mathbf{10,8 \text{ ns}}$.
#
# A resposta final é que o **tempo médio de acesso do sistema é de 10,8 ns**. Esse resultado demonstra como uma cache eficiente consegue manter a velocidade do sistema muito próxima da velocidade da memória mais rápida, mesmo quando a memória principal é quase dez vezes mais lenta.

# %% [markdown]
# ![image.png](attachment:6fc7200d-eb7d-4af0-a4b2-85513b65b43b.png)

# %% [markdown]
# ## Resolução da Questão 27
# Para descobrir quantos bits são necessários para o endereço, usamos a regra de **2 elevado a uma potência**. Primeiro, transformamos o valor de **128G** em uma potência de 2. O número **128** é o mesmo que **2 elevado a 7** e o prefixo **G** (Giga) representa **2 elevado a 30**. Somando os expoentes (7 + 30), temos um total de **2 elevado a 37**. Portanto, são necessários **37 bits** para endereçar todas as células dessa memória.
#
# ## Resolução da Questão 28
# Seguindo a mesma lógica para uma memória de **32K**, fazemos a conversão: o número **32** é igual a **2 elevado a 5** e o prefixo **K** (Quilo) representa **2 elevado a 10**. Somando esses valores (5 + 10), chegamos ao resultado de **2 elevado a 15**. Isso significa que seriam requeridos **15 bits** de endereço para conseguir identificar cada uma das células dessa memória.

# %% [markdown]
# ![image.png](attachment:4ffda5d8-f5b4-46b3-865d-0331fc235623.png)

# %% [markdown]
# ## Resolução da Questão 31
#
# Para resolver esse problema, vamos pensar na imagem como uma grande grade cheia de pontinhos (pixels), onde cada ponto guarda uma informação de cor. O exercício diz que cada um desses pontos ocupa **4 bytes** na memória do computador.
#
# ## Parte A: Memória para uma única imagem
#
# Primeiro, precisamos descobrir quantos pontos existem no total nessa imagem que tem **640 por 420**. Multiplicando esses dois valores, descobrimos que a imagem é formada por **268.800 pontos**. Como cada ponto gasta **4 bytes**, multiplicamos o total de pontos pelo tamanho de cada um:
# * 268.800 pontos $\times$ 4 bytes = **1.075.200 bytes**.
#
# Portanto, uma única imagem precisa de **1.075.200 bytes** para ser guardada.
#
# ## Parte B: Memória para 10 imagens em Megabytes
#
# Agora o objetivo é saber o espaço para **10 imagens** iguais a essa, mas o resultado precisa estar na unidade **Megabytes (MB)**. Primeiro, calculamos o total em bytes:
# * 1.075.200 bytes $\times$ 10 = **10.752.000 bytes**.
#
# Para transformar esse valor gigante em Megabytes, usamos a regra de que **1 Mega** na informática vale **1.048.576 bytes** ($2^{20}$).
# * 10.752.000 / 1.048.576 = **10,25 MB** (aproximadamente).
#
# Sendo assim, 10 imagens ocupariam cerca de **10,25 Megabytes**.
#
# ## Parte C: Quantas imagens cabem em 128MB de RAM
#
# Nesta última parte, temos um computador com **128MB de memória RAM** e queremos saber quantas fotos dessas cabem dentro dele ao mesmo tempo.
# Primeiro, vamos transformar esses 128MB em bytes para podermos comparar:
# * 128 $\times$ 1.048.576 bytes = **134.217.728 bytes**.
#
# Agora, dividimos esse espaço total da memória RAM pelo tamanho de uma única imagem que calculamos na Parte A:
# * 134.217.728 / 1.075.200 = **124,83**.
#
# Como o computador não armazena "pedaços" de imagem de forma útil nesse cálculo, arredondamos para baixo. O resultado final é que cabem **124 imagens inteiras** na memória de 128MB desse computador.

# %% [markdown]
# ![image.png](attachment:8a6e3d31-f40c-4620-8439-9de81ff512ec.png)

# %% [markdown]
# ## Resolução da Questão 32
#
# Para resolver esse problema, precisamos descobrir primeiro quantas **células** a memória tem e qual é o **tamanho** de cada uma delas em bits, para depois transformar tudo em **bytes**.
#
# ## Descobrindo o número de células
#
# O enunciado diz que a memória ROM tem **16 linhas de endereçamento**. Na informática, o número de células (N) é sempre **2 elevado à quantidade de linhas de endereço**.
# Fazendo a conta:
# * 2 elevado a 16 = **64K células** (ou 65.536 posições de memória).
#
# ## Descobrindo o tamanho da célula
#
# As **linhas de saída de dados** indicam quantos bits saem da memória de cada vez, o que corresponde ao tamanho de cada célula (M).
# Como são **4 linhas de saída**, sabemos que:
# * Cada célula guarda exatamente **4 bits**.
#
# ## Cálculo da capacidade total em bytes
#
# Agora que temos esses dois valores, multiplicamos o número de células pelo tamanho de cada uma para achar o total de bits (T):
# * 65.536 células x 4 bits = **262.144 bits** (que é o mesmo que 256K bits).
#
# Como a pergunta quer o resultado final em **bytes**, e sabemos que cada byte tem **8 bits**, fazemos a divisão final:
# * 262.144 bits / 8 = **32.768 bytes**.
#
# Portanto, nessa memória ROM podem ser armazenados **32.768 bytes** (ou **32 KB**).

# %% [markdown]
# ![image.png](attachment:fa098925-1e9e-4926-b94f-f776d09a9b75.png)

# %% [markdown]
# ## Poder de processamento vs Capacidade de armazenamento
#
# Essa afirmação **não é válida** porque ela mistura dois conceitos de hardware que funcionam de formas independentes dentro de um computador. O **poder de processamento** está ligado diretamente à Unidade Central de Processamento (UCP ou CPU) e à sua velocidade para executar cálculos e instruções por segundo. Já o ato de **armazenar programas** é uma função das unidades de memória, como o disco rígido (HD), o SSD ou a própria memória principal.
#
# ## Por que a velocidade não define o espaço
#
# Um computador pode ter um processador extremamente rápido e moderno, mas se ele tiver um disco rígido com pouca **capacidade**, ele não conseguirá guardar muitos programas. Da mesma forma, um computador antigo e lento pode ter um HD imenso e conseguir armazenar milhares de arquivos e softwares, mesmo que demore muito tempo para conseguir abrir cada um deles. Na **hierarquia de memória**, o processador fica no topo buscando velocidade, enquanto a base da pirâmide (memória secundária) foca em oferecer o máximo de espaço possível pelo menor custo.
#
# ## A única ligação técnica entre os dois
#
# Existe apenas um detalhe técnico onde o processador limita o armazenamento, mas isso tem a ver com a sua **arquitetura** e não com o seu "poder" ou velocidade. O tamanho do **endereçamento** do processador define o máximo de memória RAM (memória principal) que o sistema consegue identificar. Por exemplo, um processador de **32 bits** só consegue "enxergar" e usar até **4GB de RAM**, enquanto um de **64 bits** consegue gerenciar uma quantidade absurdamente maior, chegando a **16 Exabytes**. Mesmo assim, isso define o limite de quanto o computador pode usar ao mesmo tempo, e não a quantidade total de programas que você pode deixar instalados no seu disco rígido.

# %% [markdown]
# ![image.png](attachment:a4635103-5468-4901-bf81-f17cac2edefe.png)

# %% [markdown]
# ## Validade da afirmação sobre a Memória Principal
#
# Essa afirmação **não é tecnicamente válida**. Aumentar a capacidade da Memória Principal (RAM) não torna o acesso aos meios magnéticos, como o disco rígido, fisicamente mais rápido. O **tempo de acesso** de um dispositivo é definido pela sua tecnologia de construção e pela velocidade de seus próprios circuitos. Se um disco rígido (HD) leva entre **8 e 30 milissegundos** para localizar uma informação, ele continuará levando esse mesmo tempo, independentemente de haver mais ou menos memória RAM disponível no sistema.
#
# ## Por que o computador parece mais veloz
#
# O que ocorre na prática é uma melhora no **desempenho geral** do sistema, e não um aumento na velocidade do disco em si. De acordo com a **hierarquia de memória**, a Memória Principal é muito mais rápida (acesso entre **50 e 80 nanossegundos**) do que a memória secundária (HDs e disquetes). Quando você aumenta a RAM, o computador consegue manter mais dados "carregados" nela, evitando que o processador precise buscar informações com frequência na base da pirâmide, que é a parte mais lenta do sistema.
#
# ## Diferença entre as tecnologias
#
# É importante lembrar que essas memórias utilizam tecnologias totalmente distintas: a RAM é uma **memória de semicondutores**, enquanto os discos rígidos e disquetes são de **meio magnético**. Como o acesso aos meios magnéticos envolve componentes mecânicos que são muito mais lentos, a única forma de realmente acelerar o acesso a esses dados seria trocar o dispositivo por uma tecnologia superior, como um **SSD**, que possui velocidades de transferência significativamente maiores que os HDs tradicionais.

# %% [markdown]
# ![image.png](attachment:32ecd0d8-5c1a-4696-ba81-279e19f596a7.png)

# %% [markdown]
# ## Os três caminhos de comunicação entre o processador e a memória
#
# A comunicação entre o cérebro do computador (processador) e a sua memória principal acontece através de três tipos de barramentos, que funcionam como "estradas" para os dados e sinais. Cada um desses caminhos tem uma função muito específica e uma regra sobre para qual lado a informação pode viajar.
#
# ## O Barramento de Dados
#
# O **barramento de dados** é o caminho responsável por carregar a informação propriamente dita, como um número ou uma letra, entre a Memória Principal e o processador. Ele faz a ligação entre o componente chamado RDM (Registrador de Dados da Memória) e a memória para que as transferências ocorram. Como o computador precisa tanto buscar um dado guardado quanto salvar um dado novo, esse barramento é **bidirecional**, o que significa que o fluxo de sinais pode ir e voltar pelos mesmos fios.
#
# ## O Barramento de Endereços
#
# O **barramento de endereços** tem a função exclusiva de levar os bits que representam o endereço da célula que o processador quer acessar. Ele conecta o registrador REM (Registrador de Endereços da Memória) diretamente à Memória Principal. Diferente do anterior, o fluxo de sinais aqui é **unidirecional**, pois apenas o processador indica para a memória onde ele quer mexer; a memória não envia endereços de volta para o processador.
#
# ## O Barramento de Controle
#
# O **barramento de controle** é formado por fios condutores que servem para organizar e comandar o que deve ser feito no sistema. Por ele passam sinais fundamentais como o de escrita (**WRITE**), o de leitura (**READ**). Esse conjunto de fios interliga o processador à memória para coordenar essas tarefas e o seu fluxo de sinais é **bidirecional**, permitindo que as ordens e as respostas de estado circulem entre os dois lados.

# %% [markdown]
# ![image.png](attachment:75659160-125f-4eca-b642-9f240c74cb71.png)

# %% [markdown]
# ![image.png](attachment:f0e431f4-e564-479d-bb6a-77d3f6d0b7e3.png)\
# **Parte (a): Operação de Escrita (Processo Destrutivo)**\
# Esta operação consiste em armazenar ou gravar uma informação em um local específico da memória.\
# Fluxo de Dados: Uma cópia de um valor (dado ou informação) é transferida da UCP (Unidade Central de Processamento) para a MP (Memória Principal).\
# Ação no Endereço: O sistema identifica o endereço de destino (por exemplo, o endereço 1000) e grava o novo conteúdo sobre o anterior.
# Natureza Destrutiva: Ela é considerada naturalmente destrutiva porque o novo dado é gravado "por cima" dos bits que estavam naquele local, apagando-os permanentemente.\
# Exemplo da Figura: O valor 11110 sai da UCP e é armazenado na célula de endereço 1000 da MP, destruindo o valor anterior 00110 que ali residia.\
# ![image.png](attachment:caf37571-3437-4154-984f-852a3178524c.png)\
# **Parte (b): Operação de Leitura (Processo Não Destrutivo)**\
# Esta operação consiste em recuperar ou buscar um elemento que já está guardado na memória para uso do sistema.
# Fluxo de Dados: O valor armazenado em um endereço específico da MP é transferido (uma cópia) para a UCP.Natureza Não Destrutiva: Ao contrário da escrita, a leitura não deve ser destrutiva.\
#  O processo apenas providencia a transferência de uma cópia da informação para o local de destino, enquanto o valor original permanece intacto no local de origem (a MP).\
# Exemplo da Figura: O valor 10011, armazenado no endereço 0110 da MP, é transferido para a UCP.\
#  Após a operação, o valor 10011 continua disponível no endereço 0110 da memória principal.

# %% [markdown]
# ![image.png](attachment:15aeccf2-561a-4c54-b751-3bd5ba90fa20.png)

# %% [markdown]
# Para resolver a **Questão 13**, precisamos calcular o deslocamento (offset) na memória causado pelos grupos de letras que vêm antes do "J" e somar esse valor ao endereço inicial fornecido.
#
# Aqui está o passo a passo da resolução:
#
# ### 1. Identificar a posição do "J" e os grupos anteriores
# O problema diz que os caracteres são escritos em grupos de **128 caracteres iguais**, seguindo a ordem alfabética (As, depois Bs, e assim por diante).
# *   Para chegar ao primeiro **J**, que é a 10ª letra do alfabeto, precisamos pular **9 grupos completos** (A, B, C, D, E, F, G, H e I).
#
# ### 2. Calcular o deslocamento total (em bytes)
# Sabemos que cada caractere ocupa **8 bits (1 byte)** e que cada célula da memória armazena exatamente **1 byte**. Portanto, cada letra ocupa uma posição de endereço.
# *   **Total de caracteres antes do J:** 9 grupos $\times$ 128 caracteres por grupo = **1.152 caracteres**.
# *   Como cada um ocupa 1 byte, o deslocamento é de **1.152 bytes**.
#
# ### 3. Converter o deslocamento para Hexadecimal
# O endereço inicial está em hexadecimal (**27FA**), então precisamos converter os 1.152 bytes (decimal) para a base 16:
# *   $1.152 / 16 = 72$, sobra **0**.
# *   $72 / 16 = 4$, sobra **8**.
# *   $4 / 16 = 0$, sobra **4**.
# *   Resultado: **$480_{16}$**.
#
# ### 4. Calcular o endereço final
# Agora, basta somar o deslocamento ao endereço de partida:
# *   **Endereço Inicial:** $27FA_{16}$
# *   **Deslocamento:** $480_{16}$
#
# **Soma hexadecimal passo a passo:**
# 1.  **A + 0 = A** (O valor 10 permanece igual).
# 2.  **F + 8 = 23** em decimal. Em hexadecimal: $23 - 16 = \mathbf{7}$ (com **"vai 1"**).
# 3.  **7 + 4 + 1 (reserva) = 12**. O número 12 em hexadecimal é a letra **C**.
# 4.  **2 + 0 = 2**.
#
# O endereço correspondente ao local onde está armazenado o **1.º J** é **$2C7A_{16}$**.

# %% [markdown]
# ![image.png](attachment:78e72c51-4699-4a3e-9f17-49baf353d933.png)

# %% [markdown]
# Para resolver essa questão,precisamos comparar o **custo total** dos dois sistemas de memória. A ideia é descobrir a partir de que ponto a economia no preço por bit da DRAM compensa o custo mais alto da interface dela.
#
# Aqui estão os dados que o problema passou:\
# Interface DRAM: R 5,00\
# Interface SRAM: R 1,00\
# Custo por bit DRAM: R 0,00001\
# Custo por bit SRAM: R 0,00002
#
# ### 1. Montando as equações de custo
# Vamos chamar a quantidade de bits de $x$. O custo total de cada sistema é a soma do preço da interface com o preço total dos bits:
#
# *   **Custo SRAM** $= 1,00 + 0,00002 \cdot x$
# *   **Custo DRAM** $= 5,00 + 0,00001 \cdot x$
#
# ### 2. Comparando os custos
# Para que a memória DRAM seja mais barata, o custo total dela precisa ser menor que o da SRAM:
# $$5,00 + 0,00001x < 1,00 + 0,00002x$$
#
# ### 3. Isolando o $x$
# Agora é só fazer a álgebra básica:
# $$5,00 - 1,00 < 0,00002x - 0,00001x$$
# $$4,00 < 0,00001x$$
#
# Dividindo 4 por 0,00001:
# $$x > \frac{4}{0,00001}$$
# $$x > 400.000$$
#
# ### Conclusão
# O conjunto de memória dinâmica (DRAM) passa a ser mais barato quando o sistema tem **mais de 400.000 bits**.

# %% [markdown]
# ![image.png](attachment:aed1c152-2c96-45f7-8daa-fefd6844f97f.png)

# %% [markdown]
# ### 1. Estrutura de Endereçamento
# Para endereçar 8 células, o sistema utiliza **3 bits de endereço** ($A_2, A_1, A_0$). Esses bits entram em um **decodificador de 3 para 8**.
# *   **Função do Decodificador:** Ele possui 8 saídas ($D_0$ a $D_7$). Quando um endereço binário entra, apenas a saída correspondente àquele número é ativada (vai para nível 1).
# *   **Pino de Habilitação (Enable):** Seguindo o modelo da figura, existe um pino que deve estar em **1** para que qualquer saída do decodificador seja ativada.
#
# ### 2. Mapeamento da Memória (Tabela de Conteúdo)
# Este é o conteúdo "gravado" fisicamente na sua simulação:
#
# | Endereço ($A_2 A_1 A_0$) | Linha Ativa | Dado Armazenado ($S_3 S_2 S_1 S_0$) |
# | :--- | :--- | :--- |
# | 000 | $D_0$ | **1010** |
# | 001 | $D_1$ | **1100** |
# | 010 | $D_2$ | **0110** |
# | 011 | $D_3$ | **0011** |
# | 100 | $D_4$ | **1111** |
# | 101 | $D_5$ | **0001** |
# | 110 | $D_6$ | **1001** |
# | 111 | $D_7$ | **0101** |
#
# ### 3. Matriz de Portas OU (Lógica de Saída)
# As expressões lógicas que você usou para interligar as saídas do decodificador às portas OU de saída são:
#
# *   **Saída $S_3$:** $D_0 + D_1 + D_4 + D_6$ (Bit mais significativo)
# *   **Saída $S_2$:** $D_1 + D_2 + D_4 + D_7$
# *   **Saída $S_1$:** $D_0 + D_2 + D_3 + D_4$
# *   **Saída $S_0$:** $D_3 + D_4 + D_5 + D_6 + D_7$ (Bit menos significativo)
#
# ### 4. Funcionamento do Circuito
# Diferente de uma RAM, essa ROM não possui pinos de escrita (como o $R/W$ ou $WE$). O processo é puramente de **leitura**:
# 1.  Você coloca o endereço nos pinos de entrada.
# 2.  O decodificador "aponta" para a linha da célula desejada.
# 3.  As conexões físicas (representadas pelas expressões acima) conduzem o sinal de nível 1 até as portas OU correspondentes.
# 4.  O dado de 4 bits aparece instantaneamente nas saídas $S_3, S_2, S_1$ e $S_0$.
# ![image.png](attachment:3d708d3e-f450-4d40-94e0-5e46db0bba97.png)
